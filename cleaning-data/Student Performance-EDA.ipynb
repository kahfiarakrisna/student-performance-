# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import kstest, norm

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('Student_Performance_Data.csv')
df.head(20)
# Out:
#    sex  age  mother_edu  father_edu mother_job father_job  traveltime  \
# 0    F   18           4           4    at_home    teacher           2
# 1    F   17           1           1    at_home      other           1
# 2    F   15           1           1    at_home      other           1
# 3    F   15           4           2     health   services           1
# 4    F   16           3           3      other      other           1
# 5    M   16           4           3   services      other           1
# 6    M   16           2           2      other      other           1
# 7    F   17           4           4      other    teacher           2
# 8    M   15           3           2   services      other           1
# 9    M   15           3           4      other      other           1
# 10   F   15           4           4    teacher     health           1
# 11   F   15           2           1   services      other           3
# 12   M   15           4           4     health   services           1
# 13   M   15           4           3    teacher      other           2
# 14   M   15           2           2      other      other           1
# 15   F   16           4           4     health      other           1
# 16   F   16           4           4   services   services           1
# 17   F   16           3           3      other      other           3
# 18   M   17           3           2   services   services           1
# 19   M   16           4           3     health      other           1
#
#     studytime school_support family_support internet romantic  freetime  \
# 0           2            yes             no       no       no         3
# 1           2             no            yes      yes       no         3
# 2           2            yes             no      yes       no         3
# 3           3             no            yes      yes      yes         2
# 4           2             no            yes       no       no         3
# 5           2             no            yes      yes       no         4
# 6           2             no             no      yes       no         4
# 7           2            yes            yes       no       no         1
# 8           2             no            yes      yes       no         2
# 9           2             no            yes      yes       no         5
# 10          2             no            yes      yes       no         3
# 11          3             no            yes      yes       no         2
# 12          1             no            yes      yes       no         3
# 13          2             no            yes      yes       no         4
# 14          3             no            yes      yes      yes         5
# 15          1             no            yes      yes       no         4
# 16          3             no            yes      yes       no         2
# 17          2            yes            yes       no       no         3
# 18          1             no            yes      yes       no         5
# 19          1             no             no      yes       no         1
#
#     health  absences  grade
# 0        3         6     30
# 1        3         4     30
# 2        3        10     50
# 3        5         2     75
# 4        5         4     50
# 5        5        10     75
# 6        3         0     55
# 7        1         6     30
# 8        1         0     95
# 9        5         0     75
# 10       2         0     45
# 11       4         4     60
# 12       5         2     70
# 13       3         2     55
# 14       3         0     80
# 15       2         4     70
# 16       2         6     70
# 17       4         4     50
# 18       5        16     25
# 19       5         4     50

# %% [markdown]
# # EDA

# %%
#visualisasi outlier dengan boxpolot
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[num_cols])
plt.xticks(rotation=45) # Memutar label agar tidak bertumpukan
plt.title("Visualisasi Outlier dengan Boxplot")
plt.show()

# %%
# membuat heatmap untuk kolom numeric
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Calculate correlation on numeric columns only
corr = numeric_df.corr()

plt.figure(figsize=(15,10))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, annot = True, cmap='Reds', fmt='.2f')
plt.title("Korelasi Heatmap dari Data Numerik", fontsize=14, pad=15, fontweight='bold')
plt.show()
